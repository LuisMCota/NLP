# %%
import re
import emoji
import nltk
from nltk.corpus import wordnet
from nltk.corpus import stopwords
from unicodedata import normalize
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

# %%
nltk.download("stopwords")
nltk.download("punkt_tab")
nltk.download("wordnet")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/gaborro/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /home/gaborro/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package wordnet to /home/gaborro/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def preprocess_text(text):
        text = re.sub(r'http\S+|www\S+|@\w+|#', '', text)
        text = normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore')
        text = text.lower()
        text = emoji.replace_emoji(text, replace='')
        text = re.sub(r'[^a-z\s]', '', text)
        text = text.strip()
        return text

# %%
data = pd.read_csv("train.csv", header=None)
data
# Out:
#          0                                                  1  \
# 0        2                     Stuning even for the non-gamer
# 1        2              The best soundtrack ever to anything.
# 2        2                                           Amazing!
# 3        2                               Excellent Soundtrack
# 4        2  Remember, Pull Your Jaw Off The Floor After He...
# ...     ..                                                ...
# 3599995  1                                      Don't do it!!
# 3599996  1                      Looks nice, low functionality
# 3599997  1                         compact, but hard to clean
# 3599998  1                                 what is it saying?
# 3599999  2              Makes My Blood Run Red-White-And-Blue
#
#                                                          2
# 0        This sound track was beautiful! It paints the ...
# 1        I'm reading a lot of reviews saying that this ...
# 2        This soundtrack is my favorite music of all ti...
# 3        I truly like this soundtrack and I enjoy video...
# 4        If you've played the game, you know how divine...
# ...                                                    ...
# 3599995  The high chair looks great when it first comes...
# 3599996  I have used this highchair for 2 kids now and ...
# 3599997  We have a small house, and really wanted two o...
# 3599998  not sure what this book is supposed to be. It ...
# 3599999  I agree that every American should read this b...
#
# [3600000 rows x 3 columns]

# %%
data.rename(columns={0:"polarity", 1:"title", 2:"review"}, inplace=True)
data
# Out:
#          polarity                                              title  \
# 0               2                     Stuning even for the non-gamer
# 1               2              The best soundtrack ever to anything.
# 2               2                                           Amazing!
# 3               2                               Excellent Soundtrack
# 4               2  Remember, Pull Your Jaw Off The Floor After He...
# ...           ...                                                ...
# 3599995         1                                      Don't do it!!
# 3599996         1                      Looks nice, low functionality
# 3599997         1                         compact, but hard to clean
# 3599998         1                                 what is it saying?
# 3599999         2              Makes My Blood Run Red-White-And-Blue
#
#                                                     review
# 0        This sound track was beautiful! It paints the ...
# 1        I'm reading a lot of reviews saying that this ...
# 2        This soundtrack is my favorite music of all ti...
# 3        I truly like this soundtrack and I enjoy video...
# 4        If you've played the game, you know how divine...
# ...                                                    ...
# 3599995  The high chair looks great when it first comes...
# 3599996  I have used this highchair for 2 kids now and ...
# 3599997  We have a small house, and really wanted two o...
# 3599998  not sure what this book is supposed to be. It ...
# 3599999  I agree that every American should read this b...
#
# [3600000 rows x 3 columns]

# %%
data.dropna(subset=["title"], inplace=True)

# %%
data = data.astype({"title":str, "review":str})

# %%
data
# Out:
#          polarity                                              title  \
# 0               2                     Stuning even for the non-gamer
# 1               2              The best soundtrack ever to anything.
# 2               2                                           Amazing!
# 3               2                               Excellent Soundtrack
# 4               2  Remember, Pull Your Jaw Off The Floor After He...
# ...           ...                                                ...
# 3599995         1                                      Don't do it!!
# 3599996         1                      Looks nice, low functionality
# 3599997         1                         compact, but hard to clean
# 3599998         1                                 what is it saying?
# 3599999         2              Makes My Blood Run Red-White-And-Blue
#
#                                                     review
# 0        This sound track was beautiful! It paints the ...
# 1        I'm reading a lot of reviews saying that this ...
# 2        This soundtrack is my favorite music of all ti...
# 3        I truly like this soundtrack and I enjoy video...
# 4        If you've played the game, you know how divine...
# ...                                                    ...
# 3599995  The high chair looks great when it first comes...
# 3599996  I have used this highchair for 2 kids now and ...
# 3599997  We have a small house, and really wanted two o...
# 3599998  not sure what this book is supposed to be. It ...
# 3599999  I agree that every American should read this b...
#
# [3599793 rows x 3 columns]

# %%
data["clean_title"] = data["title"].apply(preprocess_text)

# %%
data.drop(columns=["title"], inplace=True)

# %%
data
# Out:
#          polarity                                             review  \
# 0               2  This sound track was beautiful! It paints the ...
# 1               2  I'm reading a lot of reviews saying that this ...
# 2               2  This soundtrack is my favorite music of all ti...
# 3               2  I truly like this soundtrack and I enjoy video...
# 4               2  If you've played the game, you know how divine...
# ...           ...                                                ...
# 3599995         1  The high chair looks great when it first comes...
# 3599996         1  I have used this highchair for 2 kids now and ...
# 3599997         1  We have a small house, and really wanted two o...
# 3599998         1  not sure what this book is supposed to be. It ...
# 3599999         2  I agree that every American should read this b...
#
#                                                clean_title
# 0                            stuning even for the nongamer
# 1                     the best soundtrack ever to anything
# 2                                                  amazing
# 3                                     excellent soundtrack
# 4        remember pull your jaw off the floor after hea...
# ...                                                    ...
# 3599995                                         dont do it
# 3599996                       looks nice low functionality
# 3599997                          compact but hard to clean
# 3599998                                  what is it saying
# 3599999                 makes my blood run redwhiteandblue
#
# [3599793 rows x 3 columns]

# %%
data.to_csv("clean_titles.csv")

# %% [markdown]
# ------------------------------

# %%
data = pd.read_csv("clean_titles.csv")
data
# Out:
#          Unnamed: 0  polarity  \
# 0                 0         2
# 1                 1         2
# 2                 2         2
# 3                 3         2
# 4                 4         2
# ...             ...       ...
# 3599788     3599995         1
# 3599789     3599996         1
# 3599790     3599997         1
# 3599791     3599998         1
# 3599792     3599999         2
#
#                                                     review  \
# 0        This sound track was beautiful! It paints the ...
# 1        I'm reading a lot of reviews saying that this ...
# 2        This soundtrack is my favorite music of all ti...
# 3        I truly like this soundtrack and I enjoy video...
# 4        If you've played the game, you know how divine...
# ...                                                    ...
# 3599788  The high chair looks great when it first comes...
# 3599789  I have used this highchair for 2 kids now and ...
# 3599790  We have a small house, and really wanted two o...
# 3599791  not sure what this book is supposed to be. It ...
# 3599792  I agree that every American should read this b...
#
#                                                clean_title
# 0                            stuning even for the nongamer
# 1                     the best soundtrack ever to anything
# 2                                                  amazing
# 3                                     excellent soundtrack
# 4        remember pull your jaw off the floor after hea...
# ...                                                    ...
# 3599788                                         dont do it
# 3599789                       looks nice low functionality
# 3599790                          compact but hard to clean
# 3599791                                  what is it saying
# 3599792                 makes my blood run redwhiteandblue
#
# [3599793 rows x 4 columns]

# %%
data.dropna(subset=["clean_title"], inplace=True)

# %%
data = data.astype({"clean_title":str})

# %%
sia = SentimentIntensityAnalyzer()
stop_words = set(stopwords.words('english'))

# %%
def get_antonym(word):
    antonyms = []
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            if lemma.antonyms():
                antonyms.extend(lemma.antonyms())
    if antonyms:
        return antonyms[0].name()  # Take the first antonym
    return word  # Return original if no antonym is found

# %%
def get_word_polarity(word):
    return sia.polarity_scores(word)["compound"]

# %%
def invert_review_polarity(review, review_polarity, polarity_threshold=0.1):
    words = review.split()  # Split review into individual words
    inverted_words = []

    for word in words:
        word_polarity = get_word_polarity(word)

        # Check if the word's polarity aligns with the review's overall polarity
        if (review_polarity == 2 and word_polarity > polarity_threshold) or \
           (review_polarity == 1 and word_polarity < -polarity_threshold):
            # Replace word with its antonym if polarity matches and threshold is exceeded
            antonym = get_antonym(word)
            if antonym:
                inverted_words.append(antonym)
            else:
                inverted_words.append(word)  # Keep the original word if no antonym exists
        else:
            inverted_words.append(word)  # Keep neutral or opposite-polarity words unchanged

    return " ".join(inverted_words)  # Reconstruct the inverted review

# %%
data["inverse_title"] = data.apply(lambda row: invert_review_polarity(row["clean_title"], row["polarity"]), axis=1)
data
# Out:
#          Unnamed: 0  polarity  \
# 0                 0         2
# 1                 1         2
# 2                 2         2
# 3                 3         2
# 4                 4         2
# ...             ...       ...
# 3599788     3599995         1
# 3599789     3599996         1
# 3599790     3599997         1
# 3599791     3599998         1
# 3599792     3599999         2
#
#                                                     review  \
# 0        This sound track was beautiful! It paints the ...
# 1        I'm reading a lot of reviews saying that this ...
# 2        This soundtrack is my favorite music of all ti...
# 3        I truly like this soundtrack and I enjoy video...
# 4        If you've played the game, you know how divine...
# ...                                                    ...
# 3599788  The high chair looks great when it first comes...
# 3599789  I have used this highchair for 2 kids now and ...
# 3599790  We have a small house, and really wanted two o...
# 3599791  not sure what this book is supposed to be. It ...
# 3599792  I agree that every American should read this b...
#
#                                                clean_title  \
# 0                            stuning even for the nongamer
# 1                     the best soundtrack ever to anything
# 2                                                  amazing
# 3                                     excellent soundtrack
# 4        remember pull your jaw off the floor after hea...
# ...                                                    ...
# 3599788                                         dont do it
# 3599789                       looks nice low functionality
# 3599790                          compact but hard to clean
# 3599791                                  what is it saying
# 3599792                 makes my blood run redwhiteandblue
#
#                                              inverse_title
# 0                            stuning even for the nongamer
# 1                    the worst soundtrack ever to anything
# 2                                                  amazing
# 3                                     excellent soundtrack
# 4        remember pull your jaw off the floor after hea...
# ...                                                    ...
# 3599788                                         dont do it
# 3599789                      looks nice high functionality
# 3599790                          compact but easy to clean
# 3599791                                  what is it saying
# 3599792                 makes my blood run redwhiteandblue
#
# [3596212 rows x 5 columns]

# %%
data.drop(columns=["Unnamed: 0"], inplace=True)
data
# Out:
#          polarity                                             review  \
# 0               2  This sound track was beautiful! It paints the ...
# 1               2  I'm reading a lot of reviews saying that this ...
# 2               2  This soundtrack is my favorite music of all ti...
# 3               2  I truly like this soundtrack and I enjoy video...
# 4               2  If you've played the game, you know how divine...
# ...           ...                                                ...
# 3599788         1  The high chair looks great when it first comes...
# 3599789         1  I have used this highchair for 2 kids now and ...
# 3599790         1  We have a small house, and really wanted two o...
# 3599791         1  not sure what this book is supposed to be. It ...
# 3599792         2  I agree that every American should read this b...
#
#                                                clean_title  \
# 0                            stuning even for the nongamer
# 1                     the best soundtrack ever to anything
# 2                                                  amazing
# 3                                     excellent soundtrack
# 4        remember pull your jaw off the floor after hea...
# ...                                                    ...
# 3599788                                         dont do it
# 3599789                       looks nice low functionality
# 3599790                          compact but hard to clean
# 3599791                                  what is it saying
# 3599792                 makes my blood run redwhiteandblue
#
#                                              inverse_title
# 0                            stuning even for the nongamer
# 1                    the worst soundtrack ever to anything
# 2                                                  amazing
# 3                                     excellent soundtrack
# 4        remember pull your jaw off the floor after hea...
# ...                                                    ...
# 3599788                                         dont do it
# 3599789                      looks nice high functionality
# 3599790                          compact but easy to clean
# 3599791                                  what is it saying
# 3599792                 makes my blood run redwhiteandblue
#
# [3596212 rows x 4 columns]

# %%
data.drop(columns=["review"], inplace=True)
data
# Out:
#          polarity                                        clean_title  \
# 0               2                      stuning even for the nongamer
# 1               2               the best soundtrack ever to anything
# 2               2                                            amazing
# 3               2                               excellent soundtrack
# 4               2  remember pull your jaw off the floor after hea...
# ...           ...                                                ...
# 3599788         1                                         dont do it
# 3599789         1                       looks nice low functionality
# 3599790         1                          compact but hard to clean
# 3599791         1                                  what is it saying
# 3599792         2                 makes my blood run redwhiteandblue
#
#                                              inverse_title
# 0                            stuning even for the nongamer
# 1                    the worst soundtrack ever to anything
# 2                                                  amazing
# 3                                     excellent soundtrack
# 4        remember pull your jaw off the floor after hea...
# ...                                                    ...
# 3599788                                         dont do it
# 3599789                      looks nice high functionality
# 3599790                          compact but easy to clean
# 3599791                                  what is it saying
# 3599792                 makes my blood run redwhiteandblue
#
# [3596212 rows x 3 columns]

# %%
data_relevant = data[~(data['clean_title'] == data['inverse_title'])]

# %%
data_relevant
# Out:
#          polarity                           clean_title  \
# 1               2  the best soundtrack ever to anything
# 7               2                        glorious story
# 10              1                             the worst
# 14              1                   awful beyond belief
# 16              2        a romantic zen baseball comedy
# ...           ...                                   ...
# 3599772         2                         a sweet scent
# 3599778         2    useful for everything boat related
# 3599781         2                         we love tyler
# 3599789         1          looks nice low functionality
# 3599790         1             compact but hard to clean
#
#                                  inverse_title
# 1        the worst soundtrack ever to anything
# 7                             inglorious story
# 10                                    the best
# 14                          nice beyond belief
# 16           a classicist zen baseball tragedy
# ...                                        ...
# 3599772                           a sour scent
# 3599778    useless for everything boat related
# 3599781                          we hate tyler
# 3599789          looks nice high functionality
# 3599790              compact but easy to clean
#
# [1145379 rows x 3 columns]

# %%
data_relevant.drop(columns=["polarity"], inplace=True)
# Out:
# /tmp/ipykernel_4867/2737680161.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_relevant.drop(columns=["polarity"], inplace=True)

# %%
data_relevant
# Out:
#                                   clean_title  \
# 1        the best soundtrack ever to anything
# 7                              glorious story
# 10                                  the worst
# 14                        awful beyond belief
# 16             a romantic zen baseball comedy
# ...                                       ...
# 3599772                         a sweet scent
# 3599778    useful for everything boat related
# 3599781                         we love tyler
# 3599789          looks nice low functionality
# 3599790             compact but hard to clean
#
#                                  inverse_title
# 1        the worst soundtrack ever to anything
# 7                             inglorious story
# 10                                    the best
# 14                          nice beyond belief
# 16           a classicist zen baseball tragedy
# ...                                        ...
# 3599772                           a sour scent
# 3599778    useless for everything boat related
# 3599781                          we hate tyler
# 3599789          looks nice high functionality
# 3599790              compact but easy to clean
#
# [1145379 rows x 2 columns]

# %%
data_relevant.rename(columns={"clean_title":"input", "inverse_title":"output"})
# Out:
#                                         input  \
# 1        the best soundtrack ever to anything
# 7                              glorious story
# 10                                  the worst
# 14                        awful beyond belief
# 16             a romantic zen baseball comedy
# ...                                       ...
# 3599772                         a sweet scent
# 3599778    useful for everything boat related
# 3599781                         we love tyler
# 3599789          looks nice low functionality
# 3599790             compact but hard to clean
#
#                                         output
# 1        the worst soundtrack ever to anything
# 7                             inglorious story
# 10                                    the best
# 14                          nice beyond belief
# 16           a classicist zen baseball tragedy
# ...                                        ...
# 3599772                           a sour scent
# 3599778    useless for everything boat related
# 3599781                          we hate tyler
# 3599789          looks nice high functionality
# 3599790              compact but easy to clean
#
# [1145379 rows x 2 columns]

# %%
data_relevant.to_csv("training_data.csv")
